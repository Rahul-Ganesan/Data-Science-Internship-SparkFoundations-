# %%
#Rahul Ganesan
#Task1

#importing libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd 
import seaborn as sns

#feeding the dataset
ds="https://raw.githubusercontent.com/AdiPersonalWorks/Random/master/student_scores%20-%20student_scores.csv"
dataset=pd.read_csv(ds)
x=dataset.iloc[:,:-1]
y=dataset.iloc[:,-1]
dataset.head()
# Out:
#    Hours  Scores
# 0    2.5      21
# 1    5.1      47
# 2    3.2      27
# 3    8.5      75
# 4    3.5      30

# %%
#splitting the dataset
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)
plt.scatter(x_train,y_train,color='red')
plt.xlabel('Hours studied')
plt.ylabel('Marks scored')
plt.title('Plotting training set')
plt.show()
# Out:
# &lt;Figure size 432x288 with 1 Axes&gt;

# %%
#training the model
from sklearn.linear_model import LinearRegression
regressor=LinearRegression()
regressor.fit(x_train,y_train)
y_pred=regressor.predict(x_test)

#plotting the results
plt.scatter(x_train,y_train,color='red')
plt.plot(x_train,regressor.predict(x_train),color='blue')
plt.xlabel('Hours studied')
plt.ylabel('Marks scored')
plt.title('Linear Regression for finding Marks')
plt.show()
# Out:
# &lt;Figure size 432x288 with 1 Axes&gt;

# %%
#comparing actual results vs Predicted results
dataframe=pd.DataFrame({'Actual':y_test,'predicted':y_pred})
dataframe.head()
# Out:
#     Actual  predicted
# 8       81  83.188141
# 16      30  27.032088
# 0       21  27.032088
# 23      76  69.633232
# 11      62  59.951153

# %%
#result for student with 9.25 hours
print(regressor.predict([[9.25]]))

#calculating accuracy of model
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# [92.38611528]
# 0.9678055545167994
