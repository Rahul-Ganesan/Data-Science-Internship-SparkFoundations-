# %% [markdown]
# Decision Tree Classification

# %%
#Rahul Ganesan
#Task 3 
#Aim:To feed iris Dataset into decision tree classifier and visualise the
#    results graphically. Hence if we feed any new data into the classifier, #    it can predict the results

# %%
#importing Libraries
import matplotlib.pyplot as plt
from sklearn import datasets
from sklearn.tree import DecisionTreeClassifier 
from sklearn import tree
import seaborn as sns
import pandas as pd

# Prepare the data data
iris = datasets.load_iris()
df=pd.DataFrame(iris.data, columns=iris.feature_names)
#takes all dimensions
X = iris.data
#takes all classified categories 
y = iris.target
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
# Fit the classifier with default hyper-parameters
classifier=DecisionTreeClassifier(random_state=42)
model=classifier.fit(X, y)
print('Decision Tree Classifer Created')
# Out:
# Decision Tree Classifer Created

# %%
df.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)
# count        150.000000
# mean           1.199333
# std            0.762238
# min            0.100000
# 25%            0.300000
# 50%            1.300000
# 75%            1.800000
# max            2.500000

# %%
df.nunique()
# Out:
# sepal length (cm)    35
# sepal width (cm)     23
# petal length (cm)    43
# petal width (cm)     22
# dtype: int64

# %%
fig=plt.figure(figsize=(25,20))
img= tree.plot_tree(classifier,feature_names=iris.feature_names,class_names=iris.target_names,filled=True)
fig.savefig("decistion_tree.png")
plt.show()
